# %%
# import common packages
# %matplotlib inline
import numpy as np
import pandas as pd


# import data 
income_df = pd.read_csv("https://raw.githubusercontent.com/DerrickYifeng/Income_Class_Prediction/master/clean_data_draft.csv")

# %% [markdown]
# # Data Cleaning
# ## Missing Values

# %%
income_df.isnull().sum()
# Out:
# age                  0
# work_class        2800
# fnlwgt               1
# education            1
# education_num        1
# martial_status       1
# occupation        2810
# relationship         1
# race                 1
# sex                  1
# capital_gain         1
# capital_loss         1
# hours_per_week       1
# native_country     858
# income               1
# dtype: int64

# %%
income_df = income_df.dropna()

# %%
print(income_df.isnull().sum())
print("The number of observations left is", income_df.shape[0])
# Out:
# age               0
# work_class        0
# fnlwgt            0
# education         0
# education_num     0
# martial_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64
# The number of observations left is 45222

# %% [markdown]
# ## Feature Exploration
#
# ### Varible Types
# Note that the type of Age should be float.

# %%
income_df.dtypes
# Out:
# age                object
# work_class         object
# fnlwgt            float64
# education          object
# education_num     float64
# martial_status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital_gain      float64
# capital_loss      float64
# hours_per_week    float64
# native_country     object
# income             object
# dtype: object

# %%
# Import seaborn 
import seaborn as sns
import matplotlib as plt

# Change Age to numeric 
income_df["age"] = pd.to_numeric(income_df["age"])

# %% [markdown]
# ### Data Overview
#
# Notice that there are 16,7,14,41 levels for education, martial status, occupation, and native country. These parameter may need further cleaning.

# %%
income_df.describe(include = 'all')
# Out:
#                  age work_class        fnlwgt education  education_num  \
# count   45222.000000      45222  4.522200e+04     45222   45222.000000
# unique           NaN          7           NaN        16            NaN
# top              NaN    Private           NaN   HS-grad            NaN
# freq             NaN      33307           NaN     14783            NaN
# mean       38.547941        NaN  1.897347e+05       NaN      10.118460
# std        13.217870        NaN  1.056392e+05       NaN       2.552881
# min        17.000000        NaN  1.349200e+04       NaN       1.000000
# 25%        28.000000        NaN  1.173882e+05       NaN       9.000000
# 50%        37.000000        NaN  1.783160e+05       NaN      10.000000
# 75%        47.000000        NaN  2.379260e+05       NaN      13.000000
# max        90.000000        NaN  1.490400e+06       NaN      16.000000
#
#              martial_status     occupation relationship    race    sex  \
# count                 45222          45222        45222   45222  45222
# unique                    7             14            6       5      2
# top      Married-civ-spouse   Craft-repair      Husband   White   Male
# freq                  21055           6020        18666   38903  30527
# mean                    NaN            NaN          NaN     NaN    NaN
# std                     NaN            NaN          NaN     NaN    NaN
# min                     NaN            NaN          NaN     NaN    NaN
# 25%                     NaN            NaN          NaN     NaN    NaN
# 50%                     NaN            NaN          NaN     NaN    NaN
# 75%                     NaN            NaN          NaN     NaN    NaN
# max                     NaN            NaN          NaN     NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week  native_country  income
# count   45222.000000  45222.000000    45222.000000           45222   45222
# unique           NaN           NaN             NaN              41       2
# top              NaN           NaN             NaN   United-States   <=50K
# freq             NaN           NaN             NaN           41292   34014
# mean     1101.430344     88.595418       40.938017             NaN     NaN
# std      7506.430084    404.956092       12.007508             NaN     NaN
# min         0.000000      0.000000        1.000000             NaN     NaN
# 25%         0.000000      0.000000       40.000000             NaN     NaN
# 50%         0.000000      0.000000       40.000000             NaN     NaN
# 75%         0.000000      0.000000       45.000000             NaN     NaN
# max     99999.000000   4356.000000       99.000000             NaN     NaN

# %% [markdown]
# ### Response Varible -- Income
#
# Notice that the Income is imbalanced distributed. A stratefied splitting would be considered as approperiate.

# %%
sns.countplot(income_df['income'])
display(pd.crosstab(index=income_df['income'],columns='count'))
# Out:
# col_0   count
# income
#  <=50K  34014
#  >50K   11208

# %% [markdown]
# ### Numeric Variables
#
# #### Age

# %%
sns.distplot(income_df["age"],bins = 20, hist_kws=dict(edgecolor="k", linewidth=2))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### fnlwgt

# %%
sns.distplot(income_df['fnlwgt'],bins = 20, hist_kws=dict(edgecolor="k", linewidth=2))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### Education Number

# %%
sns.distplot(income_df["education_num"],bins = 10, hist_kws=dict(edgecolor="k", linewidth=2))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### Capital Gain
# Notice that there exists a very extreme value at the right side of the distribution plot, which indicating potential mistake in data collecting process

# %%
sns.distplot(income_df["capital_gain"],bins = 10, hist_kws=dict(edgecolor="k", linewidth=2))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# explore the extreme values
income_df[income_df['capital_gain']>60000]

# Note that people with all the extreme values have income larger than 50K
# This indicates that we can discrete this feature to predict the response variable before applying our model
# Out:
#        age         work_class    fnlwgt      education  education_num  \
# 1246    54       Self-emp-inc  166459.0    Prof-school           15.0
# 1368    52            Private  152234.0        HS-grad            9.0
# 1482    53       Self-emp-inc  263925.0        HS-grad            9.0
# 1528    52            Private  118025.0      Bachelors           13.0
# 1616    46            Private  370119.0    Prof-school           15.0
# 1682    43            Private  176270.0      Bachelors           13.0
# 1765    49            Private  159816.0      Bachelors           13.0
# 1771    50            Private  171338.0   Some-college           10.0
# 1826    22   Self-emp-not-inc  202920.0        HS-grad            9.0
# 2103    43       Self-emp-inc  172826.0   Some-college           10.0
# 2319    65       Self-emp-inc  139272.0      Bachelors           13.0
# 2361    26            Private  256000.0    Prof-school           15.0
# 2707    52   Self-emp-not-inc   64045.0    Prof-school           15.0
# 3105    46            Private  176814.0    Prof-school           15.0
# 3175    36            Private  208358.0    Prof-school           15.0
# 3368    40   Self-emp-not-inc  223881.0    Prof-school           15.0
# 3836    52       Self-emp-inc   90363.0    Prof-school           15.0
# 4389    32       Self-emp-inc   46807.0        HS-grad            9.0
# 4421    53            Private   88842.0        HS-grad            9.0
# 4625    47            Private  345493.0    Prof-school           15.0
# 4898    37   Self-emp-not-inc  362062.0    Prof-school           15.0
# 5098    39       Self-emp-inc  114844.0    Prof-school           15.0
# 5184    38            Private  146091.0      Doctorate           16.0
# 5473    44            Private  332401.0    Prof-school           15.0
# 5588    57       Self-emp-inc  159028.0    Prof-school           15.0
# 6002    51            Private   44000.0        Masters           14.0
# 6035    78   Self-emp-not-inc  316261.0      Bachelors           13.0
# 6225    36            Private  383518.0   Some-college           10.0
# 6524    49       Self-emp-inc  362795.0        Masters           14.0
# 6751    54   Self-emp-not-inc  269068.0    Prof-school           15.0
# ...    ...                ...       ...            ...            ...
# 41983   40            Private  219869.0        HS-grad            9.0
# 42138   62            Private   93997.0      Doctorate           16.0
# 42233   30          State-gov  352045.0        Masters           14.0
# 42263   48            Private  349986.0    Prof-school           15.0
# 42357   28            Private  126060.0        HS-grad            9.0
# 42458   46            Private  117849.0        Masters           14.0
# 42640   45            Private  252242.0      Doctorate           16.0
# 42936   41            Private   94113.0        HS-grad            9.0
# 42976   31            Private  203463.0        Masters           14.0
# 43019   59       Self-emp-inc   76860.0        5th-6th            3.0
# 43708   51   Self-emp-not-inc  275924.0      Bachelors           13.0
# 44353   49       Self-emp-inc  172246.0      Bachelors           13.0
# 44721   50   Self-emp-not-inc   98180.0   Some-college           10.0
# 45263   47            Private  131160.0      Bachelors           13.0
# 45394   52            Private   89041.0        Masters           14.0
# 45424   41   Self-emp-not-inc   49448.0        HS-grad            9.0
# 45601   46            Private  106662.0      Bachelors           13.0
# 45612   35            Private  194668.0    Prof-school           15.0
# 45740   50       Self-emp-inc  209642.0   Some-college           10.0
# 45930   42       Self-emp-inc  203233.0    Prof-school           15.0
# 46379   43       Self-emp-inc   27444.0      Bachelors           13.0
# 46574   52            Private  122412.0      Doctorate           16.0
# 47012   40       Self-emp-inc   46221.0      Doctorate           16.0
# 47072   41   Self-emp-not-inc  143046.0        Masters           14.0
# 47186   48   Self-emp-not-inc  196707.0      Doctorate           16.0
# 47740   32       Self-emp-inc  225053.0      Bachelors           13.0
# 48583   61   Self-emp-not-inc  151369.0        Masters           14.0
# 48592   36            Private  224566.0      Bachelors           13.0
# 48599   42            Private   32878.0      Bachelors           13.0
# 48630   59       Self-emp-inc  177271.0    Prof-school           15.0
#
#             martial_status        occupation    relationship  \
# 1246    Married-civ-spouse    Prof-specialty         Husband
# 1368    Married-civ-spouse   Exec-managerial         Husband
# 1482    Married-civ-spouse             Sales         Husband
# 1528    Married-civ-spouse   Exec-managerial         Husband
# 1616    Married-civ-spouse    Prof-specialty         Husband
# 1682    Married-civ-spouse   Exec-managerial         Husband
# 1765    Married-civ-spouse    Prof-specialty            Wife
# 1771    Married-civ-spouse   Exec-managerial         Husband
# 1826         Never-married    Prof-specialty       Unmarried
# 2103    Married-civ-spouse             Sales         Husband
# 2319    Married-civ-spouse             Sales         Husband
# 2361    Married-civ-spouse    Prof-specialty         Husband
# 2707    Married-civ-spouse    Prof-specialty         Husband
# 3105    Married-civ-spouse    Prof-specialty         Husband
# 3175              Divorced    Prof-specialty   Not-in-family
# 3368    Married-civ-spouse    Prof-specialty         Husband
# 3836    Married-civ-spouse    Prof-specialty         Husband
# 4389    Married-civ-spouse      Craft-repair         Husband
# 4421    Married-civ-spouse   Exec-managerial         Husband
# 4625    Married-civ-spouse    Prof-specialty         Husband
# 4898    Married-civ-spouse    Prof-specialty         Husband
# 5098    Married-civ-spouse    Prof-specialty         Husband
# 5184    Married-civ-spouse   Exec-managerial            Wife
# 5473    Married-civ-spouse    Prof-specialty         Husband
# 5588    Married-civ-spouse    Prof-specialty         Husband
# 6002    Married-civ-spouse    Prof-specialty            Wife
# 6035         Never-married   Exec-managerial   Not-in-family
# 6225    Married-civ-spouse      Adm-clerical            Wife
# 6524              Divorced    Prof-specialty       Unmarried
# 6751    Married-civ-spouse    Prof-specialty         Husband
# ...                    ...               ...             ...
# 41983   Married-civ-spouse   Farming-fishing         Husband
# 42138   Married-civ-spouse   Exec-managerial         Husband
